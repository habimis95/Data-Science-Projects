# %%
import findspark
findspark.init()

# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName('Recommendation_Beauty').getOrCreate()

# %%
data = spark.read.json('data/Beauty_5.json')

# %%
data.show(5, truncate=True)
# Out:
# +----------+-------+-------+--------------------+-----------+--------------+------------+--------------------+--------------+
# |      asin|helpful|overall|          reviewText| reviewTime|    reviewerID|reviewerName|             summary|unixReviewTime|
# +----------+-------+-------+--------------------+-----------+--------------+------------+--------------------+--------------+
# |7806397051| [3, 4]|    1.0|Very oily and cre...|01 30, 2014|A1YJEY40YUW4SE|      Andrea|Don't waste your ...|    1391040000|
# |7806397051| [1, 1]|    3.0|This palette was ...|04 18, 2014| A60XNB876KYML|  Jessica H.|         OK Palette!|    1397779200|
# |7806397051| [0, 1]|    4.0|The texture of th...| 09 6, 2013|A3G6XNM240RMWA|       Karen|       great quality|    1378425600|
# |7806397051| [2, 2]|    2.0|I really can't te...| 12 8, 2013|A1PQFP6SAJ6D80|       Norah|Do not work on my...|    1386460800|
# |7806397051| [0, 0]|    3.0|It was a little s...|10 19, 2013|A38FVHZTNQ271F|   Nova Amor|          It's okay.|    1382140800|
# +----------+-------+-------+--------------------+-----------+--------------+------------+--------------------+--------------+
# only showing top 5 rows

# %%
data_sub = data.select(['asin', 'overall', 'reviewerID'])

# %%
data_sub.count()
# Out:
# 198502

# %%
from pyspark.sql.functions import col, udf
from pyspark.sql.functions import isnan, when, count, col

# %%
data_sub.show(5, truncate = True)
# Out:
# +----------+-------+--------------+
# |      asin|overall|    reviewerID|
# +----------+-------+--------------+
# |7806397051|    1.0|A1YJEY40YUW4SE|
# |7806397051|    3.0| A60XNB876KYML|
# |7806397051|    4.0|A3G6XNM240RMWA|
# |7806397051|    2.0|A1PQFP6SAJ6D80|
# |7806397051|    3.0|A38FVHZTNQ271F|
# +----------+-------+--------------+
# only showing top 5 rows

# %%
data_sub.select([count(when(col(c).isNull(), c)).alias(c) for c in
                 data_sub.columns]).toPandas().T
# Out:
#             0
# asin        0
# overall     0
# reviewerID  0

# %%
# Distinct users and movies
users = data_sub.select('reviewerID').distinct().count()
products = data_sub.select('asin').distinct().count()
numerator = data_sub.count()

# %%
display(numerator, users, products)
# Out:
# 198502
# 22363
# 12101

# %%
# Number of rating matrix could contain if no empty cells
denominator = users * products
denominator
# Out:
# 270614663

# %%
# Calculating sparsity 
sparsity = 1 - (numerator * 1.0 / denominator)
print('Sparsity: ', sparsity)
# Out:
# Sparsity:  0.9992664772935825

# %%
from pyspark.ml.evaluation import RegressionEvaluator
from pyspark.ml.recommendation import ALS

# %%
# Converting String to index
from pyspark.ml.feature import StringIndexer
from pyspark.ml import Pipeline
from pyspark.sql.functions import col
indexer = StringIndexer(inputCol = 'asin',
                        outputCol = 'asin_idx')

# Indexer identifies categories in the data
indexer_model = indexer.fit(data_sub)

# Indexer creates a new column with numeric index values
data_indexed = indexer_model.transform(data_sub)

# Repeat the process for the other categorical feature
indexer1 = StringIndexer(inputCol = 'reviewerID',
                         outputCol = 'reviewerID_idx')
indexer1_model = indexer1.fit(data_indexed)
data_indexed = indexer1_model.transform(data_indexed)

# %%
data_indexed.show(5, truncate = True)
# Out:
# +----------+-------+--------------+--------+--------------+
# |      asin|overall|    reviewerID|asin_idx|reviewerID_idx|
# +----------+-------+--------------+--------+--------------+
# |7806397051|    1.0|A1YJEY40YUW4SE|  6959.0|       18008.0|
# |7806397051|    3.0| A60XNB876KYML|  6959.0|       10825.0|
# |7806397051|    4.0|A3G6XNM240RMWA|  6959.0|        5924.0|
# |7806397051|    2.0|A1PQFP6SAJ6D80|  6959.0|       12357.0|
# |7806397051|    3.0|A38FVHZTNQ271F|  6959.0|        6087.0|
# +----------+-------+--------------+--------+--------------+
# only showing top 5 rows

# %%
data_indexed.select([count(when(col(c).isNull(),c)).alias (c) for c in 
                    data_indexed.columns]).toPandas().T
# Out:
#                 0
# asin            0
# overall         0
# reviewerID      0
# asin_idx        0
# reviewerID_idx  0

# %%
# Smaller dataset so we will use 0.8/0.2
training, test = data_indexed.randomSplit([0.8,0.2])

# %%
# Creating ALS model and fitting data
als = ALS(maxIter = 5, 
          regParam=0.09,
          rank=25, 
          userCol='reviewerID_idx', 
          itemCol = 'asin_idx',
          ratingCol = 'overall',
          coldStartStrategy='drop',
          nonnegative=True)
model = als.fit(training)

# %%
# Evaluate the model by computing the RMSE on the test data
predictions = model.transform(test)

# %%
predictions.select(['asin_idx', 'reviewerID_idx', 
                    'overall', 'prediction']).show(5)
# Out:
# +--------+--------------+-------+----------+
# |asin_idx|reviewerID_idx|overall|prediction|
# +--------+--------------+-------+----------+
# |   148.0|         385.0|    5.0| 5.5424514|
# |   148.0|         236.0|    5.0| 4.1931453|
# |   148.0|         330.0|    1.0| 4.1391478|
# |   148.0|       19062.0|    5.0| 3.4681797|
# |   148.0|        2422.0|    5.0| 3.9887984|
# +--------+--------------+-------+----------+
# only showing top 5 rows

# %%
evaluator = RegressionEvaluator(metricName = 'rmse', 
                                labelCol = 'overall',
                                predictionCol = 'prediction')
rmse = evaluator.evaluate(predictions)
print('Root-mean-square error = ' + str(rmse))
# Out:
# Root-mean-square error = 1.3446319135143865

# %%
# On average,  this model is ~ 1.2 from perfect recommendations

# %% [markdown]
# ## Providing Recommendations: for all users

# %%
# get 20 recommendations which have highest rating
user_recs = model.recommendForAllUsers(20)

# %%
for user in user_recs.head(5):
    print(user)
    print('\n')
# Out:
# Row(reviewerID_idx=1580, recommendations=[Row(asin_idx=6183, rating=8.20853042602539), Row(asin_idx=4274, rating=8.187591552734375), Row(asin_idx=11679, rating=8.116562843322754), Row(asin_idx=6604, rating=8.01150894165039), Row(asin_idx=3527, rating=7.951577186584473), Row(asin_idx=10127, rating=7.948854923248291), Row(asin_idx=8893, rating=7.896306037902832), Row(asin_idx=11655, rating=7.814083576202393), Row(asin_idx=11625, rating=7.74952507019043), Row(asin_idx=9900, rating=7.733482360839844), Row(asin_idx=9940, rating=7.711333274841309), Row(asin_idx=6658, rating=7.684535026550293), Row(asin_idx=5177, rating=7.68311071395874), Row(asin_idx=8232, rating=7.661252021789551), Row(asin_idx=4026, rating=7.659734725952148), Row(asin_idx=8046, rating=7.654044151306152), Row(asin_idx=5519, rating=7.653414249420166), Row(asin_idx=8742, rating=7.584081172943115), Row(asin_idx=11342, rating=7.567073822021484), Row(asin_idx=7885, rating=7.507442474365234)])
#
#
# Row(reviewerID_idx=4900, recommendations=[Row(asin_idx=11625, rating=7.469553470611572), Row(asin_idx=7900, rating=7.4354448318481445), Row(asin_idx=4274, rating=7.314598083496094), Row(asin_idx=6604, rating=7.307768821716309), Row(asin_idx=6183, rating=7.290558815002441), Row(asin_idx=11722, rating=7.269193649291992), Row(asin_idx=9900, rating=7.190659523010254), Row(asin_idx=8046, rating=7.1778974533081055), Row(asin_idx=11655, rating=7.153142929077148), Row(asin_idx=10938, rating=7.1410112380981445), Row(asin_idx=4026, rating=7.099048137664795), Row(asin_idx=8232, rating=7.0685505867004395), Row(asin_idx=9246, rating=7.0625457763671875), Row(asin_idx=8414, rating=7.0287299156188965), Row(asin_idx=10127, rating=7.0233588218688965), Row(asin_idx=4727, rating=7.007050514221191), Row(asin_idx=11086, rating=6.985608100891113), Row(asin_idx=11521, rating=6.973880767822266), Row(asin_idx=11947, rating=6.968739032745361), Row(asin_idx=10241, rating=6.965072154998779)])
#
#
# Row(reviewerID_idx=5300, recommendations=[Row(asin_idx=11679, rating=7.906644344329834), Row(asin_idx=4274, rating=7.623971462249756), Row(asin_idx=6183, rating=7.597802639007568), Row(asin_idx=10127, rating=7.570293426513672), Row(asin_idx=6604, rating=7.540538787841797), Row(asin_idx=7885, rating=7.527339935302734), Row(asin_idx=5177, rating=7.445173263549805), Row(asin_idx=11625, rating=7.395402431488037), Row(asin_idx=3654, rating=7.391809463500977), Row(asin_idx=9900, rating=7.389344215393066), Row(asin_idx=3527, rating=7.331596851348877), Row(asin_idx=11655, rating=7.2524518966674805), Row(asin_idx=8046, rating=7.238894462585449), Row(asin_idx=6658, rating=7.228677272796631), Row(asin_idx=8477, rating=7.193264007568359), Row(asin_idx=4879, rating=7.192862510681152), Row(asin_idx=4533, rating=7.15941047668457), Row(asin_idx=9247, rating=7.130318641662598), Row(asin_idx=11673, rating=7.113527297973633), Row(asin_idx=8013, rating=7.092039585113525)])
#
#
# Row(reviewerID_idx=6620, recommendations=[Row(asin_idx=10071, rating=7.070805072784424), Row(asin_idx=10450, rating=7.070056915283203), Row(asin_idx=12002, rating=7.069234848022461), Row(asin_idx=10013, rating=7.069234848022461), Row(asin_idx=10279, rating=7.068760395050049), Row(asin_idx=10958, rating=7.0687408447265625), Row(asin_idx=9653, rating=6.658802509307861), Row(asin_idx=8386, rating=6.630146026611328), Row(asin_idx=7108, rating=6.509852886199951), Row(asin_idx=7885, rating=6.49110746383667), Row(asin_idx=10938, rating=6.479526042938232), Row(asin_idx=11625, rating=6.418437957763672), Row(asin_idx=9900, rating=6.3426194190979), Row(asin_idx=9736, rating=6.270821571350098), Row(asin_idx=11086, rating=6.254127025604248), Row(asin_idx=7421, rating=6.213478088378906), Row(asin_idx=9940, rating=6.203709125518799), Row(asin_idx=8893, rating=6.197887420654297), Row(asin_idx=4274, rating=6.175692081451416), Row(asin_idx=11455, rating=6.160737991333008)])
#
#
# Row(reviewerID_idx=7240, recommendations=[Row(asin_idx=4274, rating=6.3386125564575195), Row(asin_idx=11625, rating=6.324603080749512), Row(asin_idx=10127, rating=6.275928020477295), Row(asin_idx=6183, rating=6.258726119995117), Row(asin_idx=11655, rating=6.255763530731201), Row(asin_idx=4879, rating=6.221275329589844), Row(asin_idx=9900, rating=6.195072650909424), Row(asin_idx=8232, rating=6.1538825035095215), Row(asin_idx=10938, rating=6.147097587585449), Row(asin_idx=7732, rating=6.131743431091309), Row(asin_idx=4026, rating=6.128565788269043), Row(asin_idx=6604, rating=6.106751441955566), Row(asin_idx=7108, rating=6.098674297332764), Row(asin_idx=11722, rating=6.0506486892700195), Row(asin_idx=5177, rating=6.0184245109558105), Row(asin_idx=8046, rating=6.0007500648498535), Row(asin_idx=11673, rating=5.985666275024414), Row(asin_idx=3527, rating=5.974567413330078), Row(asin_idx=9778, rating=5.962826728820801), Row(asin_idx=11404, rating=5.956897258758545)])

# %% [markdown]
# ## Converting back to string form
#
# > Indented block

# %%
import pandas as pd
recs = model.recommendForAllUsers(10).toPandas()
nrecs = recs.recommendations.apply(pd.Series) \
            .merge(recs, right_index = True, left_index = True) \
            .drop(['recommendations'], axis = 1) \
            .melt(id_vars = ['reviewerID_idx'], value_name = 'recommendation') \
            .drop('variable', axis = 1) \
            .dropna()
nrecs = nrecs.sort_values('reviewerID_idx')
nrecs = pd.concat([nrecs['recommendation'].apply(pd.Series),
                   nrecs['reviewerID_idx']], axis = 1)
nrecs.columns = [
    'ProductID_index',
    'Rating', 
    'UserID_index'
]

# %%
md = data_indexed.select(['reviewerID', 'reviewerID_idx',
                          'asin', 'asin_idx'])
md = md.toPandas()
dict1 = dict(zip(md['reviewerID_idx'], md['reviewerID']))
dict2 = dict(zip(md['asin_idx'], md['asin']))
nrecs['reviewerID'] = nrecs['UserID_index'].map(dict1)
nrecs['asin'] = nrecs['ProductID_index'].map(dict2)
nrecs = nrecs.sort_values('reviewerID')
nrecs.reset_index(drop = True, inplace = True)
new = nrecs[['reviewerID','asin', 'Rating']]
new['recommendations'] = list(zip(new.asin, new.Rating))
res = new[['reviewerID', 'recommendations']]
res_new = res['recommendations'].groupby([res.reviewerID])\
                                .apply(list).reset_index()
# Out:
# c:\users\habiw\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()

# %%
res_new
# Out:
#                   reviewerID  \
# 0      A00414041RD0BXM6WK0GX
# 1      A00473363TJ8YSZ3YAGG9
# 2      A00700212KB3K0MVESPIY
# 3       A0078719IR14X3NNUG0F
# 4      A01198201H0E3GHV2Z17I
# ...                      ...
# 22355          AZZNK89PXD006
# 22356          AZZQXL8VDCFTV
# 22357          AZZT1ERHBSNQ8
# 22358          AZZU6NXB8YJN9
# 22359          AZZZLM1E5JJ8C
#
#                                          recommendations
# 0      [(B00HFP4JZU, 4.942602634429932), (B000EVGOS2,...
# 1      [(B003JMYYQW, 4.40961217880249), (B0016KTQ0I, ...
# 2      [(B007L5P7YQ, 6.5778093338012695), (B00161IKD6...
# 3      [(B000VCN6KI, 7.923923492431641), (B000VOHH56,...
# 4      [(B000TUB4BU, 6.999694347381592), (B007L8QLU2,...
# ...                                                  ...
# 22355  [(B00464EC1E, 3.4921135902404785), (B00381A7OW...
# 22356  [(B000ZECIDS, 5.694683074951172), (B0029OIWNC,...
# 22357  [(B001FO2GW0, 6.32636833190918), (B00381A7OW, ...
# 22358  [(B00HHECHLC, 5.361822605133057), (B0055HYT78,...
# 22359  [(B000QAVNA0, 5.521671295166016), (B00HHECHLC,...
#
# [22360 rows x 2 columns]
